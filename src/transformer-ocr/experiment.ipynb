# %% [markdown]
# ## Import Libs

# %% [markdown]
# ## Model

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F 

class PatchEmbed(nn.Module):
    def __init__(self, img_height, img_width, patch=16, d_model=256):
        super().__init__()
        assert img_height % patch == 0 and img_width % patch == 0, "Image dimensions must be divisible by the patch size."
